# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import sqlite3
from sqlalchemy import create_engine

# %%
#Create databse
conn = sqlite3.connect('inventory.db')

# %%
#Checking the table present in the database
tables = pd.read_sql_query("SELECT name from sqlite_master WHERE type = 'table'", conn)
tables
# Out:
#                    name
# 0             purchases
# 1        vendor_invoice
# 2       begin_inventory
# 3         end_inventory
# 4       purchase_prices
# 5                 sales
# 6  vendor_sales_summary

# %%
for table in tables['name']:
    print('-'*50, f'{table}','-'*50)
    print('Count of records:', pd.read_sql(f"SELECT count(*) as count from {table}", conn)['count'].values[0])
    display(pd.read_sql(f"SELECT * FROM {table} limit 5", conn))
# Out:
# -------------------------------------------------- purchases --------------------------------------------------
# Count of records: 2372474
#    False          InventoryId  Store  Brand                   Description  \
# 0      0    69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno
# 1      1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide
# 2      2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced
# 3      3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide
# 4      4    76_DONCASTER_2034     76   2034     Glendalough Double Barrel
#
#     Size  VendorNumber                   VendorName  PONumber      PODate  \
# 0  750mL           105  ALTAMAR BRANDS LLC               8124  2023-12-21
# 1  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# ...

# %%
# In a terminal cell:
# !pip install dask

import dask.dataframe as dd

# This doesn't load the file into memory yet; it just "looks" at it
ddf = dd.read_csv('data/sales.csv')

# Perform your database ingestion
ddf.to_sql('sales', uri='sqlite:///inventory.db', if_exists='replace')

# %%
df = pd.read_csv('data/sales.csv', chunksize=100000)
for i, chunk in enumerate(df):
    chunk.to_parquet(f'data/sales_part_{i}.parquet')

# %% [markdown]
# ## Checking vendor data

# %%
purchases = pd.read_sql_query("SELECT * FROM purchases WHERE VendorNumber = 4466" ,conn)
purchases
# Out:
#         False          InventoryId  Store  Brand  \
# 0           1     30_CULCHETH_5255     30   5255
# 1           2    34_PITMERDEN_5215     34   5215
# 2           3  1_HARDERSFIELD_5255      1   5255
# 3        8091    38_GOULCREST_5215     38   5215
# 4        8092  59_CLAETHORPES_5215     59   5215
# ...       ...                  ...    ...    ...
# 2187  2314214     81_PEMBROKE_5215     81   5215
# 2188  2314215   62_KILMARNOCK_5255     62   5255
# 2189  2314216    34_PITMERDEN_5215     34   5215
# 2190  2314217     6_GOULCREST_5215      6   5215
# 2191  2314218    35_HALIVAARA_5255     35   5255
#
#                        Description   Size  VendorNumber  \
# 0     TGI Fridays Ultimte Mudslide  1.75L          4466
# 1     TGI Fridays Long Island Iced  1.75L          4466
# 2     TGI Fridays Ultimte Mudslide  1.75L          4466
# 3     TGI Fridays Long Island Iced  1.75L          4466
# 4     TGI Fridays Long Island Iced  1.75L          4466
# ...

# %%
purchase_prices = pd.read_sql_query("SELECT * FROM purchase_prices WHERE VendorNumber = 4466" ,conn)
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoice = pd.read_sql_query("SELECT * FROM vendor_invoice WHERE VendorNumber = 4466" ,conn)
vendor_invoice
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
sales = pd.read_sql_query("SELECT * FROM sales WHERE VendorNo = 4466" ,conn)
sales
# Out:
#        index          InventoryId  Store  Brand                   Description  \
# 0      13370  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# 1      13371  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# 2      13372  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# 3      13373  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# 4      13374  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced
# ...      ...                  ...    ...    ...                           ...
# 2878  529704     14_BROMWICH_5255     14   5255  TGI Fridays Ultimte Mudslide
# 2879  529705     14_BROMWICH_5255     14   5255  TGI Fridays Ultimte Mudslide
# 2880  529706     14_BROMWICH_5255     14   5255  TGI Fridays Ultimte Mudslide
# 2881  529707     14_BROMWICH_5255     14   5255  TGI Fridays Ultimte Mudslide
# 2882  529708     14_BROMWICH_5255     14   5255  TGI Fridays Ultimte Mudslide
#
# ...

# %%
purchases.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
purchase_prices
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
purchases.head(5)
# Out:
#    False          InventoryId  Store  Brand                   Description  \
# 0      1     30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide
# 1      2    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced
# 2      3  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide
# 3   8091    38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced
# 4   8092  59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced
#
#     Size  VendorNumber                   VendorName  PONumber      PODate  \
# 0  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 1  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 2  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8137  2023-12-22
# 3  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8207  2023-12-27
# 4  1.75L          4466  AMERICAN VINTAGE BEVERAGE        8207  2023-12-27
#
# ...

# %%
purchases['Brand']
# Out:
# 0       5255
# 1       5215
# 2       5255
# 3       5215
# 4       5215
#         ...
# 2187    5215
# 2188    5255
# 2189    5215
# 2190    5215
# 2191    5255
# Name: Brand, Length: 2192, dtype: int64

# %%
vendor_invoice['PONumber'].nunique()
# Out:
# 55

# %%
sales.groupby(['Brand'])[['SalesDollars','SalesPrice','SalesQuantity']].sum()
# Out:
#        SalesDollars  SalesPrice  SalesQuantity
# Brand
# 3140        7936.89     4780.32            611
# 5215       22264.86    14925.51           1714
# 5255       26863.32    17744.34           2068

# %% [markdown]
# * The purchases table contains the actual purchase data, including the data for purchases, products (brands) purchased by vendors, the amount paid (in dollars), and the quantity purchased.
# * The purchase price column is derived from the purchase_price table, which provides product-wise actual and purchase prices. The combination vendor and brand is unique in this table.
# * The vendor_invoice table aggregated data from the purchase table, summarizing quantity and dollar amounts, along with an additional column for freight. This table maintains uniqueness based on vendor PO number.
# * The sales table captures actual sales transactions, detailing the brands purchased by vendors, the quantity sold , the selling price, and the revenue earned.
#
#   ---
#
# As the data that we need to analyze is distributed in different tables, we need to create a summary table containing it.
# * purchase transaction made by vendors
# * sales transaction data.
# * freight costs for each vendor.
# * actual product prices from vendors.

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
freight_summary = pd.read_sql_query("""SELECT VendorNumber, VendorName, SUM(Freight) as Freight_Cost FROM vendor_invoice 
Group by VendorNumber""", conn)
freight_summary
# Out:
#      VendorNumber                               VendorName  Freight_Cost
# 0               2  IRA GOLDMAN AND WILLIAMS, LLP                   27.08
# 1              54              AAPER ALCOHOL & CHEMICAL CO          0.48
# 2              60              ADAMBA IMPORTS INTL INC            367.52
# 3             105              ALTAMAR BRANDS LLC                  62.39
# 4             200              AMERICAN SPIRITS EXCHANGE            6.19
# ..            ...                                      ...           ...
# 121         98450              Serralles Usa LLC                  856.02
# 122         99166              STARK BREWING COMPANY              130.09
# 123        172662                 SWEETWATER FARM                 178.34
# 124        173357              TAMWORTH DISTILLING                202.50
# 125        201359              FLAVOR ESSENCE INC                   0.09
#
# [126 rows x 3 columns]

# %%
purchases.columns
# Out:
# Index(['False', 'InventoryId', 'Store', 'Brand', 'Description', 'Size',
#        'VendorNumber', 'VendorName', 'PONumber', 'PODate', 'ReceivingDate',
#        'InvoiceDate', 'PayDate', 'PurchasePrice', 'Quantity', 'Dollars',
#        'Classification'],
#       dtype='object')

# %%
purchase_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""SELECT p.VendorNumber,
p.VendorName, 
p.Brand,
p.PurchasePrice, 
pp.Volume,
pp.Price AS ActualPrice,
SUM(p.Quantity) AS TotalQuantity,
SUM(p.Dollars) AS TotalPurchaseDollars
FROM purchases p
JOIN purchase_prices pp
ON p.Brand = pp.Brand
WHERE p.PurchasePrice >0
GROUP BY  p.VendorNumber, 
    p.VendorName, 
    p.Brand, 
    p.PurchasePrice, 
    pp.Volume, 
    pp.Price
ORDER BY TotalPurchaseDollars""",
conn)
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice Volume  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71     50
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47    200
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74     50
# 3              8004  SAZERAC CO INC                5683           0.39     50
# 4              9815  WINE GROUP INC                8527           1.32    750
# ...             ...                          ...    ...            ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545          21.89   1750
# 10688          3960  DIAGEO NORTH AMERICA INC      4261          16.17   1750
# 10689         17035  PERNOD RICARD USA             8068          18.24   1750
# 10690          4425        MARTIGNETTI COMPANIES   3405          23.19   1750
# 10691          1128  BROWN-FORMAN CORP             1233          26.27   1750
#
# ...

# %%
sales.columns
# Out:
# Index(['index', 'InventoryId', 'Store', 'Brand', 'Description', 'Size',
#        'SalesQuantity', 'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume',
#        'Classification', 'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
pd.read_sql_query("""SELECT VendorNo,
Brand,
SUM(SalesDollars) AS TotalSalesDollars,
SUM(SalesPrice) AS TotalSalesPrice,
SUM(SalesQuantity) AS TotalSalesQuantity,
SUM(ExciseTax) AS TotalExciseTax
FROM sales
GROUP BY VendorNo, Brand
ORDER BY TotalSalesDollars DESC""",
conn)
# Out:
#       VendorNo  Brand  TotalSalesDollars  TotalSalesPrice  TotalSalesQuantity  \
# 0         3960   4261         2058278.54        184272.78               91846
# 1         1128   1233         1657105.70        283398.43               45430
# 2        17035   8068         1491934.04        197824.33               59446
# 3         3960   3545         1454691.53        226983.47               46047
# 4         4425   3405         1448558.82        233682.22               47714
# ...        ...    ...                ...              ...                 ...
# 9232       660   2134               2.49             2.49                   1
# 9233      3252   3933               1.98             0.99                   2
# 9234     10050   3623               1.98             1.98                   2
# 9235      9206   2773               0.99             0.99                   1
# 9236      8004   5287               0.98             0.98                   2
#
#       TotalExciseTax
# ...

# %%
import time

# Note: Added missing comma after VendorNumber and fixed the JOIN logic
optimized_query = """
WITH aggregated_sales AS (
    SELECT 
        VendorNo, 
        Brand,
        SUM(SalesDollars) AS TotalSalesDollars,
        SUM(SalesPrice) AS TotalSalesPrice,
        SUM(SalesQuantity) AS TotalSalesQuantity,
        SUM(ExciseTax) AS TotalExciseTax
    FROM sales
    GROUP BY VendorNo, Brand
),
aggregated_vi AS (
    SELECT 
        VendorNumber,   -- Added missing comma here
        SUM(Quantity) AS TotalQuantity,
        SUM(Dollars) AS TotalDollars,
        SUM(Freight) AS FreightCost
    FROM vendor_invoice
    GROUP BY VendorNumber
)
SELECT
    pp.VendorNumber, 
    pp.VendorName,
    pp.Description,
    pp.Brand,
    pp.Price AS ActualPrice,
    pp.Volume,
    pp.PurchasePrice,
    s.TotalSalesDollars,
    s.TotalSalesPrice,
    s.TotalSalesQuantity,
    s.TotalExciseTax,
    vi.TotalQuantity,
    vi.TotalDollars,
    vi.FreightCost
FROM purchase_prices pp
LEFT JOIN aggregated_sales s 
    ON pp.VendorNumber = s.VendorNo AND pp.Brand = s.Brand
LEFT JOIN aggregated_vi vi 
    ON pp.VendorNumber = vi.VendorNumber
"""

start = time.time()
# Using 'engine' is usually safer in modern pandas, but 'conn' works if defined
vendor_sales_summary = pd.read_sql_query(optimized_query, conn) 
end = time.time()

print(f"Total Time: {(end - start):.2f} seconds")
# Out:
# Total Time: 29.98 seconds

# %%
vendor_sales_summary
# Out:
#        VendorNumber                   VendorName  \
# 0              8320  SHAW ROSS INT L IMP LTD
# 1              1128  BROWN-FORMAN CORP
# 2              1128  BROWN-FORMAN CORP
# 3              9165  ULTRA BEVERAGE COMPANY LLP
# 4              7245  PROXIMO SPIRITS INC.
# ...             ...                          ...
# 12256         90024  VINILANDIA USA
# 12257          4425        MARTIGNETTI COMPANIES
# 12258         10754  PERFECTA WINES
# 12259          9744  FREDERICK WILDMAN & SONS
# 12260         10754  PERFECTA WINES
#
#                         Description  Brand  ActualPrice Volume  PurchasePrice  \
# 0       Gekkeikan Black & Gold Sake     58        12.99    750           9.28
# 1          Herradura Silver Tequila     62        36.99    750          28.67
# 2        Herradura Reposado Tequila     63        38.99    750          30.46
# 3              No. 3 London Dry Gin     72        34.99    750          26.11
# ...

# %% [markdown]
# This query generates a vendor-wise sales and purchases summary, which is valuable for:
# #### Performance Optimization:
# * This query involves heavy joins and aggregations on large datasets like sales and purchases.
# * Storing the pre-aggregated results avoids repeated expense computation.
# * Helps in analyzing sales, purchases, and pricing for different vendors and brands.
# * Future benefits of storing this data for faster dashboarding & Reporting.
# * Instead of running expensive query of each time, dashboards can fetch data very quickly from vendor_sales_summary.

# %% [markdown]
# #### Data Cleaning in vendor_sales_summary

# %%
vendor_sales_summary.dtypes
# Out:
# VendorNumber            int64
# VendorName             object
# Description            object
# Brand                   int64
# ActualPrice           float64
# Volume                 object
# PurchasePrice         float64
# TotalSalesDollars     float64
# TotalSalesPrice       float64
# TotalSalesQuantity    float64
# TotalExciseTax        float64
# TotalQuantity         float64
# TotalDollars          float64
# FreightCost           float64
# dtype: object

# %%
vendor_sales_summary.isnull().sum()
# Out:
# VendorNumber             0
# VendorName               0
# Description              1
# Brand                    0
# ActualPrice              0
# Volume                   1
# PurchasePrice            0
# TotalSalesDollars     3024
# TotalSalesPrice       3024
# TotalSalesQuantity    3024
# TotalExciseTax        3024
# TotalQuantity            6
# TotalDollars             6
# FreightCost              6
# dtype: int64

# %%
# errors='coerce' turns "Unknown" into NaN
vendor_sales_summary['Volume'] = pd.to_numeric(vendor_sales_summary['Volume'], errors='coerce')

# %%
# Replace 'Unknown' with 0 first, then convert
vendor_sales_summary['Volume'] = vendor_sales_summary['Volume'].replace('Unknown', 0).astype(float)

# %%
vendor_sales_summary.fillna(0, inplace =True)

# %%
vendor_sales_summary['VendorName'] = vendor_sales_summary['VendorName'] .str.strip()

# %%
vendor_sales_summary['GrossProfit'] = vendor_sales_summary['TotalSalesDollars'] - vendor_sales_summary['TotalDollars']

# %%
vendor_sales_summary['ProfitMargin'] = (vendor_sales_summary['GrossProfit']/ vendor_sales_summary['TotalSalesDollars'])*100

# %%
vendor_sales_summary['StockTurnover'] = vendor_sales_summary['TotalSalesQuantity']/vendor_sales_summary['TotalQuantity']

# %%
vendor_sales_summary['StockToPurchaseRatio'] = vendor_sales_summary['TotalSalesDollars']/ vendor_sales_summary['TotalDollars']

# %% [markdown]
# #### Create Table

# %%
cursor = conn.cursor()

# %%
cursor.execute("""
CREATE TABLE vendor_sales_summary(
VendorNumber INT,
VendorName VARCHAR(100),
Description VARCHAR(100),
Brand INT, 
ActualPrice DECIMAL(10,2),
Volume,
PurchasePrice DECIMAL(10,2),
TotalSalesDollars INT,
TotalSalesPrice DECIMAL(10,2),
TotalSalesQuantity INT, 
TotalExciseTax DECIMAL(15,2), 
TotalQuantity INT, 
TotalDollars DECIMAL(15,2),
FreightCost DECIMAL(15,2), 
GrossProfit DECIMAL(15,2), 
ProfitMargin DECIMAL(15,2), 
StockTurnover DECIMAL(15,2),
StockPurchaseRatio DECIMAL(15,2),
PRIMARY KEY(VendorNumber, Brand)
)
""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cursor.execute("""
#       2 CREATE TABLE vendor_sales_summary(
#       3 VendorNumber INT,
#       4 VendorName VARCHAR(100),
#       5 Description VARCHAR(100),
#       6 Brand INT,
#       7 ActualPrice DECIMAL(10,2),
#       8 Volume,
#       9 PurchasePrice DECIMAL(10,2),
#      10 TotalSalesDollars INT,
#      11 TotalSalesPrice DECIMAL(10,2),
#      12 TotalSalesQuantity INT,
#      13 TotalExciseTax DECIMAL(15,2),
#      14 TotalQuantity INT,
#      15 TotalDollars DECIMAL(15,2),
#      16 FreightCost DECIMAL(15,2),
#      17 GrossProfit DECIMAL(15,2),
#      18 ProfitMargin DECIMAL(15,2),
#      19 StockTurnover DECIMAL(15,2),
#      20 StockPurchaseRatio DECIMAL(15,2),
#      21 PRIMARY KEY(VendorNumber, Brand)
#      22 )
#      23 """)
#
# ...

# %%
vendor_sales_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Description', 'Brand', 'ActualPrice',
#        'Volume', 'PurchasePrice', 'TotalSalesDollars', 'TotalSalesPrice',
#        'TotalSalesQuantity', 'TotalExciseTax', 'TotalQuantity', 'TotalDollars',
#        'FreightCost', 'GrossProfit', 'ProfitMargin', 'StockTurnover',
#        'StockToPurchaseRatio'],
#       dtype='object')

# %%
vendor_sales_summary.to_sql('vendor_sales_summary', conn, if_exists= 'replace' , index= False)
# Out:
# 12261

# %%
pd.read_sql_query("SELECT * FROM vendor_sales_summary", conn)
# Out:
#        VendorNumber                  VendorName                   Description  \
# 0              8320     SHAW ROSS INT L IMP LTD   Gekkeikan Black & Gold Sake
# 1              1128           BROWN-FORMAN CORP      Herradura Silver Tequila
# 2              1128           BROWN-FORMAN CORP    Herradura Reposado Tequila
# 3              9165  ULTRA BEVERAGE COMPANY LLP          No. 3 London Dry Gin
# 4              7245        PROXIMO SPIRITS INC.     Three Olives Tomato Vodka
# ...             ...                         ...                           ...
# 12256         90024              VINILANDIA USA     Ferreira 10-Yr Tawny Port
# 12257          4425       MARTIGNETTI COMPANIES     Sanford Santa Rita Pnt Nr
# 12258         10754              PERFECTA WINES  Neal One Lane Bridg Cab Svgn
# 12259          9744    FREDERICK WILDMAN & SONS       Folonari Pnt Nr Venezie
# 12260         10754              PERFECTA WINES     Calera Viognier Mt Harlan
#
# ...

# %%
vendor_sales_summary.to_sql('vendor_sales_summary', conn, if_exists = 'replace', index = False)
# Out:
# 12261

# %%
import pandas as pd
import sqlite3
from sqlalchemy import create_engine
import logging
# Assuming ingest_db is in your ingestion.py file
from Ingestion_db import ingest_db 

def create_vendor_summary(conn):
    '''Merges tables using CTEs to create a vendor summary.'''
    # Note: I added the JOIN to purchase_prices (pp) so pp.Price and pp.Volume work
    query = """
    WITH FreightSummary AS (
        SELECT VendorNumber, SUM(Freight) AS FreightCost
        FROM vendor_invoice
        GROUP BY VendorNumber
    ),
    PurchaseSummary AS (
        SELECT
            p.VendorNumber, p.VendorName, p.Brand, p.Description,
            p.PurchasePrice,
            pp.Price AS ActualPrice,
            pp.Volume,
            SUM(p.Quantity) AS TotalPurchaseQuantity,
            SUM(p.Dollars) AS TotalPurchaseDollars
        FROM purchases p
        LEFT JOIN purchase_prices pp ON p.Brand = pp.Brand 
        WHERE p.PurchasePrice > 0
        GROUP BY p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice, pp.Price, pp.Volume
    ),
    SalesSummary AS (
        SELECT
            VendorNo, Brand,
            SUM(SalesQuantity) AS TotalSalesQuantity,
            SUM(SalesDollars) AS TotalSalesDollars,
            SUM(SalesPrice) AS TotalSalesPrice,
            SUM(ExciseTax) AS TotalExciseTax
        FROM sales
        GROUP BY VendorNo, Brand
    )
    SELECT
        ps.*,
        ss.TotalSalesQuantity, ss.TotalSalesDollars,
        ss.TotalSalesPrice, ss.TotalExciseTax,
        fs.FreightCost
    FROM PurchaseSummary ps
    LEFT JOIN SalesSummary ss ON ps.VendorNumber = ss.VendorNo AND ps.Brand = ss.Brand
    LEFT JOIN FreightSummary fs ON ps.VendorNumber = fs.VendorNumber
    ORDER BY ps.TotalPurchaseDollars DESC
    """
    return pd.read_sql_query(query, conn)

def clean_data(df):
    '''Cleans data and calculates business KPIs.'''
    # 1. Handle Volume
    df['Volume'] = df['Volume'].replace('Unknown', 0).astype(float)
    
    # 2. Fill missing sales/freight with 0
    df.fillna(0, inplace=True)

    # 3. Clean strings
    df['VendorName'] = df['VendorName'].str.strip()
    df['Description'] = df['Description'].str.strip()
    
    # 4. KPI Calculations (Using correct column names from the SQL query)
    # Gross Profit = Sales - Cost of Goods (TotalPurchaseDollars is used here as cost proxy)
    df['GrossProfit'] = df['TotalSalesDollars'] - df['TotalPurchaseDollars']
    
    # Avoid division by zero for margins
    df['ProfitMargin'] = (df['GrossProfit'] / df['TotalSalesDollars'].replace(0, 1)) * 100
    
    return df

if __name__ == '__main__':
    conn = sqlite3.connect('inventory.db')
    
    logging.info('Creating Vendor Summary Table...')
    summary_df = create_vendor_summary(conn)
    
    logging.info('Cleaning Data and calculating KPIs...')
    clean_df = clean_data(summary_df)
    
    # To see your results in the notebook:
    print(clean_df.head())
    
    # Close connection
    conn.close()
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  ActualPrice  Volume  TotalPurchaseQuantity  \
# 0          26.27        36.99  1750.0                 145080
# 1          23.19        28.99  1750.0                 164038
# 2          18.24        24.99  1750.0                 187407
# 3          16.17        22.99  1750.0                 201682
# 4          21.89        29.99  1750.0                 138109
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesDollars  \
# 0            3811251.60             45430.0         1657105.70
# ...
